# %%
import whatsapp_bot as wpb
import pandas as pd
import numpy as np

# %%
### datos de celular para el test
#data={'phone_numbers':[965992236,954302730, 977183791,965992236, 981827783, 993453473, 966504433, 934091769],"envio": 0}
data={'phone_numbers':[965992236, 965992236],"envio": 0}
cont=pd.DataFrame(data)
cont["msj"]="Prueba1"
cont.to_csv("contactos.csv", index=False)

df= pd.read_csv('contactos.csv')
df
# Out:
#    phone_numbers  envio      msj
# 0      965992236      0  Prueba1
# 1      965992236      0  Prueba1

# %%
url_directivos="https://docs.google.com/spreadsheets/d/1-1801IyR3tksm_Y8KPM7YWP7Mpx8C3tf/edit#gid=713102029"
wpb.open_directivos_EBR(url_directivos, ugel_cod="210004")
# Out:
#      index_o NUMERO_DOCUMENTO CODIGO_ROL       DRE       UGEL  ESTADO  \
# 0          5         01341590         19  DRE Puno  EL COLLAO  Activo
# 1      49979         01875610         19  DRE Puno  EL COLLAO  Activo
# 2      49968         01888335         19  DRE Puno  EL COLLAO  Activo
# 3      49967         01787987         47  DRE Puno  EL COLLAO  Activo
# 4      49963         01847403         19  DRE Puno  EL COLLAO  Activo
# ..       ...              ...        ...       ...        ...     ...
# 297    39388         42742831         47  DRE Puno  EL COLLAO  Activo
# 298    39006         42776705         19  DRE Puno  EL COLLAO  Activo
# 299    38853         42714067         47  DRE Puno  EL COLLAO  Activo
# 300    38610         80492484         19  DRE Puno  EL COLLAO  Activo
# 301    61192         30676094         47  DRE Puno  EL COLLAO  Activo
#
#      phone_numbers TELEFONO_TRABAJO  len_t  envio codooii
# 0        996020038              NaN      9      0  210004
# ...

# %%
wpb.get_excel_txt('https://docs.google.com/spreadsheets/d/1DLrgfIjw0ekiazcohkX2YF_8Rsoa8OYi-0DOKZUIqNo/edit#gid=0')
# Out:
#                                                 text enviar
# 0  Directora/or, ¿Aún no registras tus metas de a...     SI
# 1  Por favor, confirme con un "Sí", si recepcionó...     SI

# %%
## información de la función
wpb.execute_bot?
# Out:
# Signature:
# wpb.execute_bot(
#     url_bd,
#     url_sms,
#     dre_name=None,
#     ugel_cod=None,
#     var_start=None,
#     var_end=None,
#     user=None,
#     pass_user=None,
#     google_drive=False,
#     test=False,
# )
# Docstring:
# #Docstring:
#   Ejecuta el bot para el envio automático de mensajes de whatsapp usando el servicio de Callbell y los usuarios creados para Matrícula Digital.
#   Ejecutado de forma local, abre una nuevo navegador de google Chrome en modo incognito.
#   Ejecutado desde google Drive, ejecuta el código en modo 'headless', sin necesidad de abrir una ventana del navegador.
#
# Parameters
#   ----------
#   url_bd: str, url de la base de datos (BD) de directores alojada en el drive del proyecto.
#       Si se desea utilizar otra BD de números telefónicos, la base de datos debe tener como mínimo las siguientes variables:
#       ['DRE', 'UGEL', 'phone_numbers','codooii']
#   url_sms: str, url de la BD de los textos que serán envíados
# ...

# %%
url_directivos="https://docs.google.com/spreadsheets/d/1-1801IyR3tksm_Y8KPM7YWP7Mpx8C3tf/edit#gid=713102029"
url_msj='https://docs.google.com/spreadsheets/d/1DLrgfIjw0ekiazcohkX2YF_8Rsoa8OYi-0DOKZUIqNo/edit#gid=0'

wpb.execute_bot(url_bd=url_directivos, url_sms=url_msj,
                ugel_cod="210001",
                user="gestionmatricula@gmail.com",
                pass_user="qwerty",
                test=False)
# Out:
# El número de filas de la BD es:  575
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 4
#       1 url_directivos="https://docs.google.com/spreadsheets/d/1-1801IyR3tksm_Y8KPM7YWP7Mpx8C3tf/edit#gid=713102029"
#       2 url_msj='https://docs.google.com/spreadsheets/d/1DLrgfIjw0ekiazcohkX2YF_8Rsoa8OYi-0DOKZUIqNo/edit#gid=0'
# ----> 4 wpb.execute_bot(url_bd=url_directivos, url_sms=url_msj,
#       5                 ugel_cod="210001",
#       6                 user="gestionmatricula@gmail.com",
#       7                 pass_user="qwerty",
#       8                 test=False)
#
# File ~\Desktop\Python\06. Matricula Digital\Whatsappy\whatsapp_bot\driver_whatsapp.py:132, in execute_bot(url_bd, url_sms, dre_name, ugel_cod, var_start, var_end, user, pass_user, google_drive, test)
#     130 ##opening the message windown
# ...
